# %%
# !python -V
# Out:
# Python 3.13.15

# %%
# Cargar Google Drive en el entorno de ejecución de Google Colab
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')

carpeta_drive = Path('/content/drive/MyDrive/Ciencia de datos')
print(f'Carpeta disponible: {carpeta_drive}')
print(f'Existe: {carpeta_drive.exists()}')
# Out:
# Mounted at /content/drive
# Carpeta disponible: /content/drive/MyDrive/Ciencia de datos
# Existe: True

# %%
# !ls -la
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Aug 27 20:38 .
# drwxr-xr-x 1 root root 4096 Aug 27 20:20 ..
# drwxr-xr-x 4 root root 4096 Aug 24 13:27 .config
# drwx------ 5 root root 4096 Aug 27 20:38 drive
# drwxr-xr-x 1 root root 4096 Aug 24 13:28 sample_data

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, losses, metrics
import numpy as np
import matplotlib.pyplot as plt

print(f"Versión de TensorFlow: {tf.__version__}")
# Out:
# Versión de TensorFlow: 2.20.0

# %%
# !nvidia-smi
# Out:
# Thu Aug 27 20:40:42 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
